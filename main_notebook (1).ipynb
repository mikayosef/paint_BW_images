# %% [markdown]
# # <span style="color: tomato;">            Paint Black & White Photos</span>
# by: Mika Yosef
#
# <img src="mountain.jpg"/> <img src="mountain_pred.jpg"/>
#
# <!-- ![](test.jpg) -->
# <!-- ![](colorfig2.jpg) -->
#
# <!-- <img src="first_test.jpg"/> -->
#
# This project allows you to bring the image back to life.
#
# by using the dataset CIFAR10 (data that include 50K different pictures of variance objects: cats, deers, airplains, trucks etc.), I built a model, based on Neural Network.
# the model goal is to success to take a black & white picture and make it colorful.

# %%
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn

# %%
from BW_dataset import BWDataset
from net import CONVNet
from train_val import train
from preview import imshow_to_numpy
from test_and_save import test_paint
from preview import preview

torch.backends.cudnn.benchmark = True

# %% [markdown]
# # Main Definitions

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 64

#custom dataset
trainset = BWDataset(train=True, download=True,device=device)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

valset = BWDataset(train=False, download=True,device=device)
valloader = torch.utils.data.DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=2)

PATH = './data/conv_20epoch.ckpt'
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
NET = CONVNet().to(device)

criterion = nn.L1Loss().to(device)
optimizer = optim.Adam(NET.parameters(), lr=0.0001)

# %%
preview(trainloader)

# %% [markdown]
# # Train a Model

# %%
train_set_loss, val_set_loss, number_of_epochs = train(200,trainloader,valloader,optimizer,criterion, NET, PATH)
# Out:
# Val Loss: 0.207682: 100%|██████████| 200/200 [7:08:26<00:00, 128.53s/it]
# Finished Training

# %% [markdown]
# The model: CNN, 200 epochs, batch size of 64.

# %%
torch.save(NET.state_dict(), PATH)

# %%
plt.figure( figsize=(12,6))
plt.subplot(121)
plt.plot(number_of_epochs,train_set_loss,'r',label = 'Train')
plt.plot(number_of_epochs,val_set_loss,'b',label = 'Validate')
plt.xlabel('Number_of_epochs'); plt.ylabel('Loss');
plt.legend()
plt.show()

# %% [markdown]
# This graph shows that the validation loss improves as the number of epochs increase, but this is a small improvement so I did not run any more epochs

# %% [markdown]
# # Checking the validation results:
# The model shows a loss of 0.045.
# to evaluate this better, i'll print one random colorful image from the validation set, and compare it to the painting prdicted image:

# %%
val_loss = 0
with torch.no_grad():
    for idx, data in enumerate(valloader):
        # gray, color = data
        gray, color = data
        gray, color = gray.to(device), color.to(device)
        outputs = NET(gray)
        loss = criterion(outputs, color)
        val_loss += loss.item()
        imshow_to_numpy(color[0])
        plt.figure()
        imshow_to_numpy(outputs[0])
        break
    print(f"validation loss of the picture: {val_loss}")
# Out:
# validation loss of the picture: 0.20555147528648376

# %% [markdown]
# ## Reload the Model

# %% [markdown]
# I used the model I've already trained to check it ability to paint an image that wasn't included in the dataset.

# %% [markdown]
# To be able to evaluate better the results, I tryed a variance type of images to find the strength and weakness of the model.

# %% [markdown]
# below you can see some of the original gray picture and the new colorful picture by the model:

# %%
NET.load_state_dict(torch.load(PATH))
NET.eval()
# Out:
# CONVNet(
#   (conv1): Conv2d(1, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv2): Conv2d(12, 25, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv3): Conv2d(25, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv4): Conv2d(40, 55, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv5): Conv2d(55, 70, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv6): Conv2d(70, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv7): Conv2d(60, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv8): Conv2d(40, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv9): Conv2d(20, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv10): Conv2d(10, 5, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#   (conv11): Conv2d(5, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
# )

# %%
test_paint("mountain.jpg",device, NET)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_117384/1505501209.py in <module>
# ----> 1 test_paint("mountain.jpg",device, NET)
#
# c:\Users\mikay\Documents\Study\paint_BW_images\test_and_save.py in test_paint(pic_name, device, NET)
#      10     with torch.no_grad():
#      11         pic_path = pic_name
# ---> 12         with Image.open(pic_path) as im:
#      13             pic_transform = transforms.ToTensor()
#      14             pic = pic_transform(im)
#
# ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mountain.jpg'

# %%
test_paint("hippo.jpg",device, NET)

# %%
test_paint("cars2.jpg",device, NET)

# %%
test_paint("girraf.jpg",device, NET)

# %%
test_paint("football.jpg",device, NET)

# %%
test_paint("trees.jpg",device, NET)

# %%
test_paint("ski2.jpg",device, NET)

# %%
test_paint("ski6.jpg",device, NET)
